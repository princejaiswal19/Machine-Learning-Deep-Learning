# %%
import json

# %%
json_data='{"a":1,"b":2,"c":3,"d":4}'

# %%
x=json.loads(json_data)

# %%
x
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
x['c']
# Out:
# 3

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.title("Prince Graph")
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.show()
